# %%
# Try for one file first
import librosa
import os
import soundfile as sf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style as ms
from tqdm import tqdm
import pickle
import random

import IPython.display
import librosa.display
import time
import joblib
from joblib import Parallel, delayed
ms.use('seaborn-muted')
# %matplotlib inline
# Out:
# /tmp/ipykernel_3258241/3232948396.py:17: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   ms.use('seaborn-muted')

# %%
import pandas as pd
import math

labels_df = pd.read_csv('/home/arpitsah/Desktop/Projects Fall-22/DA/domain_adaptation/LSTM-DENSE/speech-emotion-recognition-iemocap/preprocess_info/df_iemocap.csv')
iemocap_dir = '/home/arpitsah/Desktop/Projects Fall-22/DA/domain_adaptation/LSTM-DENSE/speech-emotion-recognition-iemocap/data/IEMOCAP_full_release_FILES/IEMOCAP_full_release/'
save_dir = '/home/arpitsah/Desktop/Projects Fall-22/DA/domain_adaptation/LSTM-DENSE/speech-emotion-recognition-iemocap/preprocess_info/'
audio_vectors_path= save_dir + 'audio_vectors_'

# %%
sr = 22050

# %%
audio_vectors = {}
for sess in range(1, 6):
# for sess in range(4, 5):
    wav_file_path = '{}Session{}/dialog/wav/'.format(iemocap_dir, sess)
    orig_wav_files = os.listdir(wav_file_path)
    for orig_wav_file in tqdm(orig_wav_files):
        try:
            orig_wav_vector, _sr = librosa.load(wav_file_path + orig_wav_file, sr=sr)
            orig_wav_file, file_format = orig_wav_file.split('.')
            for index, row in labels_df[labels_df['wav_file'].str.contains(orig_wav_file)].iterrows():
                start_time, end_time, truncated_wav_file_name, emotion, val, act, dom = row['start_time'], row['end_time'], row['wav_file'], row['emotion'], row['val'], row['act'], row['dom']
                start_frame = math.floor(start_time * sr)
                end_frame = math.floor(end_time * sr)
                truncated_wav_vector = orig_wav_vector[start_frame:end_frame + 1]
                audio_vectors[truncated_wav_file_name] = truncated_wav_vector
        except:
            print('An exception occured for {}'.format(orig_wav_file))
    with open(save_dir + 'audio_vectors_{}.pkl'.format(sess), 'wb') as f:
        pickle.dump(audio_vectors, f)

# %%
def features(X, sample_rate):
    
    stft = np.abs(librosa.stft(X))
    
    pitches, magnitudes = librosa.piptrack(X, sr=sample_rate, S=stft, fmin=70, fmax=400)
    pitch = []
    for i in range(magnitudes.shape[1]):
        index = magnitudes[:, 1].argmax()
        pitch.append(pitches[index, i])
        
    pitch_tuning_offset = librosa.pitch_tuning(pitches)
    pitchmean = np.mean(pitch)
    pitchstd = np.std(pitch)
    pitchmax = np.max(pitch)
    pitchmin = np.min(pitch)
    
    cent = librosa.feature.spectral_centroid(y=X, sr=sample_rate)
    cent = cent / np.sum(cent)
    meancent = np.mean(cent)
    stdcent = np.std(cent)
    maxcent = np.max(cent)
    
    flatness = np.mean(librosa.feature.spectral_flatness(y=X))

    mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=12).T, axis=0)
    
    mfccsstd = np.std(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=12).T, axis=0)
    
    mfccmax = np.max(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=12).T, axis=0)    
    
    chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0)    

    mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T, axis=0)    

    contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T, axis=0)    

    zerocr = np.mean(librosa.feature.zero_crossing_rate(X))

    rms = librosa.feature.rms(X + 0.0001)[0]
    meanrms = np.mean(rms)
    stdrms = np.std(rms)
    maxrms = np.max(rms)
    
    y_harmonic = np.mean(librosa.effects.hpss(X)[0])
    sig_mean = np.mean(abs(X))
    sig_std = np.std(X)

    ext_features = np.array([
        flatness, zerocr, meancent, stdcent,
        maxcent, pitchmean, pitchmax, pitchmin, pitchstd,
        pitch_tuning_offset, meanrms, maxrms, stdrms, y_harmonic, sig_mean, sig_std])

    
    ext_features = np.concatenate((ext_features, mfccs, mfccsstd, mfccmax, chroma, mel, contrast))
    
    return ext_features

# %%
columns = ['wav_file', 'label', "flatness", "zerocr", "meancent", "stdcent", "maxcent", "pitchmean", 
           "pitchmax", "pitchmin", "pitchstd", "pitch_tuning_offset", "meanrms", "maxrms", "stdrms", 
           "y_harmonic", "sig_mean", "sig_std"]
columns_new = columns + [(lambda x: "mfcc_" + str(x))(x) for x in range(1, 13)] + [(lambda x: "mfccstd_" + str(x))(x) for x in range(1, 13)] + [(lambda x: "mfccmax_" + str(x))(x) for x in range(1, 13)] + [(lambda x: "chroma" + str(x))(x) for x in range(1, 13)] + [(lambda x: "mel" + str(x))(x) for x in range(1, 129)] + [(lambda x: "contrast" + str(x))(x) for x in range(1, 8)]
        
# columns_new

# %%
df_features = pd.DataFrame(columns=columns_new)

# %%
emotion_dict = {'ang': 0,
                'hap': 1,
                'exc': 2,
                'sad': 3,
                'fru': 4,
                'fea': 5,
                'sur': 6,
                'neu': 7,
                'xxx': 8,
                'oth': 8,
                'dis': 8}

# %%
labels_df.emotion.value_counts()
# Out:
# xxx    2506
# fru    1849
# neu    1708
# ang    1103
# sad    1084
# exc    1041
# hap     595
# sur     107
# fea      40
# oth       3
# dis       2
# Name: emotion, dtype: int64

# %%
for sess in range(1, 6):
    audio_vectors = pickle.load(open('{}{}.pkl'.format(audio_vectors_path, sess), 'rb'))
    for index, row in tqdm(labels_df[labels_df['wav_file'].str.contains('Ses0{}'.format(sess))].iterrows()):

        wav_file_name = row['wav_file']
    
        label = emotion_dict[row['emotion']]
        y = audio_vectors[wav_file_name]

        features_all = list(features(y, sr))
        
        feature_list = [wav_file_name, label] + features_all
        
        df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
        
    print("Session Finished {}".format(sess))
# Out:
# 0it [00:00, ?it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 1it [00:00,  2.18it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 2it [00:00,  2.03it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 3it [00:01,  2.72it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 4it [00:01,  3.17it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 5it [00:01,  2.93it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 6it [00:02,  2.48it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 7it [00:02,  2.42it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 8it [00:03,  1.83it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 9it [00:04,  1.83it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 10it [00:04,  1.60it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 11it [00:05,  2.02it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 12it [00:05,  2.03it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 13it [00:06,  2.13it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 14it [00:06,  2.51it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 15it [00:06,  3.11it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 16it [00:06,  3.16it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 17it [00:07,  2.95it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 18it [00:07,  2.81it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 19it [00:07,  3.17it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 20it [00:08,  3.13it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 21it [00:08,  3.36it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 22it [00:08,  3.98it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 23it [00:08,  4.63it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 24it [00:08,  4.11it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 25it [00:09,  4.01it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 26it [00:09,  4.08it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 27it [00:09,  4.59it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 28it [00:09,  5.14it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 29it [00:10,  4.16it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 30it [00:10,  4.12it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 31it [00:10,  3.74it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 32it [00:10,  3.62it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 33it [00:11,  3.42it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 34it [00:11,  3.03it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 35it [00:12,  2.94it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 36it [00:12,  2.83it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 37it [00:12,  2.75it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 38it [00:13,  3.15it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 39it [00:13,  3.07it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 40it [00:13,  2.82it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 41it [00:14,  3.08it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 42it [00:14,  3.24it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 43it [00:14,  3.36it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 44it [00:14,  4.09it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 45it [00:14,  4.07it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 46it [00:15,  3.49it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 47it [00:15,  3.43it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 48it [00:15,  4.07it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 49it [00:16,  3.36it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 50it [00:16,  3.31it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 51it [00:16,  2.92it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 52it [00:17,  3.40it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 53it [00:17,  2.98it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 54it [00:17,  3.05it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 55it [00:18,  3.40it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 56it [00:18,  3.59it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 57it [00:18,  4.33it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 58it [00:18,  3.70it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 59it [00:19,  3.98it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 60it [00:19,  3.91it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 61it [00:19,  3.07it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 62it [00:20,  3.04it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 63it [00:20,  2.21it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 64it [00:21,  2.43it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 65it [00:21,  2.82it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 66it [00:21,  3.40it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 67it [00:21,  3.95it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 68it [00:21,  4.35it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 69it [00:21,  5.07it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 70it [00:22,  2.48it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 71it [00:23,  2.91it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 72it [00:23,  2.67it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 73it [00:24,  2.00it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 74it [00:24,  2.00it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 75it [00:25,  2.16it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 76it [00:25,  2.26it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 77it [00:26,  1.92it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 78it [00:26,  2.17it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 79it [00:26,  2.67it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 80it [00:27,  2.92it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 81it [00:27,  3.33it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 82it [00:27,  2.71it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 83it [00:28,  2.94it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 84it [00:28,  3.20it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 85it [00:28,  3.43it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 86it [00:28,  3.82it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 87it [00:29,  3.02it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 88it [00:29,  2.97it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 89it [00:29,  3.10it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 90it [00:30,  2.99it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 91it [00:30,  3.32it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 92it [00:30,  3.41it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 93it [00:31,  2.50it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 94it [00:31,  2.19it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 95it [00:32,  2.42it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 96it [00:32,  2.19it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 97it [00:33,  1.51it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 98it [00:34,  1.67it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 99it [00:35,  1.57it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 100it [00:35,  1.69it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 101it [00:36,  1.77it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 102it [00:36,  1.96it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 103it [00:37,  1.64it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 104it [00:37,  1.81it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 105it [00:38,  1.83it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 106it [00:38,  2.30it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 107it [00:38,  2.83it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 108it [00:39,  2.77it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 109it [00:39,  3.46it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 110it [00:39,  3.23it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 111it [00:39,  3.17it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 112it [00:40,  3.65it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 113it [00:40,  3.84it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 114it [00:40,  3.40it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 115it [00:40,  3.91it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 116it [00:40,  4.51it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 117it [00:41,  4.64it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 118it [00:41,  4.57it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 119it [00:41,  5.12it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 120it [00:41,  4.62it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 121it [00:41,  5.16it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 122it [00:42,  4.74it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 123it [00:42,  4.11it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 124it [00:42,  4.58it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 125it [00:42,  4.04it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 126it [00:43,  3.63it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 127it [00:43,  3.95it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 128it [00:43,  4.34it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 129it [00:43,  3.94it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 130it [00:44,  4.24it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 131it [00:44,  3.19it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 132it [00:44,  3.53it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 133it [00:45,  2.83it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 134it [00:45,  2.83it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 135it [00:46,  2.90it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 136it [00:46,  3.03it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 137it [00:46,  3.37it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 138it [00:47,  2.47it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 139it [00:47,  2.58it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 140it [00:47,  2.88it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 141it [00:48,  3.19it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 142it [00:48,  3.79it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 143it [00:48,  4.24it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# /tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 145it [00:48,  4.83it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 146it [00:48,  5.04it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 147it [00:49,  4.65it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 148it [00:49,  3.78it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 149it [00:49,  3.70it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 150it [00:50,  3.50it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 151it [00:50,  3.08it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 152it [00:50,  3.71it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 153it [00:51,  3.68it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 154it [00:51,  2.55it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 102it [00:30,  1.79it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 103it [00:31,  1.95it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 104it [00:31,  1.87it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 105it [00:31,  2.11it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 106it [00:32,  2.37it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 107it [00:32,  2.14it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 108it [00:33,  2.61it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 109it [00:33,  3.17it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 110it [00:33,  2.95it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 111it [00:33,  3.40it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 112it [00:33,  3.96it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 113it [00:34,  3.31it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 114it [00:34,  3.49it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 115it [00:35,  2.55it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 116it [00:35,  3.08it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 117it [00:35,  3.52it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 118it [00:35,  4.05it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 119it [00:36,  3.58it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 120it [00:36,  3.58it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 121it [00:36,  3.47it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 122it [00:37,  2.85it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 123it [00:37,  3.45it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 124it [00:37,  3.75it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 125it [00:37,  4.35it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 126it [00:37,  4.40it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 127it [00:38,  4.07it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 128it [00:38,  3.16it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 129it [00:39,  3.09it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 130it [00:39,  2.43it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 131it [00:39,  2.89it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 132it [00:40,  3.21it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 133it [00:40,  3.42it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 134it [00:40,  3.72it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 135it [00:40,  4.15it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 136it [00:41,  3.54it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 137it [00:41,  2.47it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 138it [00:42,  2.38it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 139it [00:42,  2.91it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 140it [00:42,  3.39it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 141it [00:42,  4.05it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 142it [00:42,  4.32it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 143it [00:43,  4.01it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 144it [00:43,  3.93it/s]/tmp/ipykernel_3258241/1683439338.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
# 145it [00:43,  3.40it/s]/home/arpitsah/anaconda3/envs/domain_adaption/lib/python3.9/site-packages/librosa/core/spectrum.py:222: UserWarning: n_fft=2048 is too small for input signal of length=0
#   warnings.warn(
# 145it [00:43,  3.31it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 10
#       7 label = emotion_dict[row['emotion']]
#       8 y = audio_vectors[wav_file_name]
# ---> 10 features_all = list(features(y, sr))
#      12 feature_list = [wav_file_name, label] + features_all
#      14 df_features = df_features.append(pd.DataFrame(feature_list, index=columns_new).transpose(), ignore_index=True)
#
# Cell In[4], line 3, in features(X, sample_rate)
#       1 def features(X, sample_rate):
# ----> 3     stft = np.abs(librosa.stft(X))
#       5     pitches, magnitudes = librosa.piptrack(X, sr=sample_rate, S=stft, fmin=70, fmax=400)
#       6     pitch = []
#
# File ~/anaconda3/envs/domain_adaption/lib/python3.9/site-packages/librosa/core/spectrum.py:228, in stft(y, n_fft, hop_length, win_length, window, center, dtype, pad_mode)
#     221     if n_fft > y.shape[-1]:
#     222         warnings.warn(
#     223             "n_fft={} is too small for input signal of length={}".format(
#     224                 n_fft, y.shape[-1]
#     225             )
#     226         )
# --> 228     y = np.pad(y, int(n_fft // 2), mode=pad_mode)
#     230 elif n_fft > y.shape[-1]:
#     231     raise ParameterError(
#     232         "n_fft={} is too small for input signal of length={}".format(
#     233             n_fft, y.shape[-1]
#     234         )
#     235     )
#
# File <__array_function__ internals>:180, in pad(*args, **kwargs)
#
# File ~/anaconda3/envs/domain_adaption/lib/python3.9/site-packages/numpy/lib/arraypad.py:814, in pad(array, pad_width, mode, **kwargs)
#     812     for axis, width_pair in zip(axes, pad_width):
#     813         if array.shape[axis] == 0 and any(width_pair):
# --> 814             raise ValueError(
#     815                 "can't extend empty axis {} using modes other than "
#     816                 "'constant' or 'empty'".format(axis)
#     817             )
#     818     # passed, don't need to do anything more as _pad_simple already
#     819     # returned the correct result
#     821 elif mode == "edge":
#
# ValueError: can't extend empty axis 0 using modes other than 'constant' or 'empty'

# %%
df_features.to_csv('/home/arpitsah/Desktop/Projects Fall-22/DA/domain_adaptation/LSTM-DENSE/speech-emotion-recognition-iemocap/preprocess_info/audio_features.csv', index=False)

# %%
print(wav_file_name)
print(df_features.shape)
# Out:
# Ses05M_script01_1b_F037
# (8014, 201)
